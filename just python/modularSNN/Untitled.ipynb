# %%
import numpy as np

# %%
x = int(input("enter a value for x:"))
# Out:
# enter a value for x: 3

# %%
class Robot:
    test = 'test'
    def __init__(self, name):
        self.name = name
        self.passion = "cooking"
    def introduce_self(self):
        print("my name is " + self.name + 'and i like' + self.passion)

# %%
r1 = Robot('tom')

# %%
r1.introduce_self()
# Out:
# my name is tomand i likecooking

# %% [raw]
# sample when this works:
# model =
#     layer1 = Layer(num = 5, neurontype = LIF, signal = noise)
#     layer2 = Layer(num = 10, neurontype = LIF)
#     connect(layer1, layer2, learningrule = STDP)
# model.run(10)
# model.plot(waves, etc.)

# %%
r1.test
# Out:
# 'test'

# %%
layer1 = layers.Layer('retina', 5)

# %%
layer1.neurontype
# Out:
# 'LIFNeuron'

# %%
layer1 = layers.Layer('layer1', 5, 'LIFNeuron')
layer2 = layers.Layer('layer2', 8, 'LIFNeuron')
for t in range(10):
    layer2.neurons.step() # gives last layers input 
    layer2.neurons.plot_wave()

# %%
layer1 = layers.Layer('layer1', 5, 'LIFNeuron')

# %%
layer1.run(5)

# %%
layer2.plot_wave()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-bc905073993a> in <module>
# ----> 1 layer2.plot_wave()
#
# ~/Desktop/thomson lab/spikingNN/just python/modularSNN/layers.py in plot_wave(self)
#      37     # goes through neurons in neurontype and makes arrays holding each info
#      38     def plot_wave(self):
# ---> 39         self.neurontype.plot_wave(self)
#      40
#      41
#
# AttributeError: 'str' object has no attribute 'plot_wave'

# %%
layer2.step()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-cd8e47a3bcf1> in <module>
# ----> 1 layer2.step()
#
# ~/Desktop/thomson lab/spikingNN/just python/modularSNN/layers.py in step(self)
#      24
#      25     def step(self):
# ---> 26         self.neurontype.step(self)
#      27
#      28
#
# AttributeError: 'str' object has no attribute 'step'

# %%
np.matmul(np.ones((3,)) , np.ones((3,3)))
# Out:
# array([3., 3., 3.])

# %%
import numpy as np

# %%
import snn as snn
model = snn.Network()
layer1 = snn.Layer('layer1', 3, 'LIFNeuron')
layer2 = snn.Layer('layer1', 5, 'LIFNeuron')
model.add(layer1)
model.add(layer2)
#snn.connection(layer1, layer2, rule = 'STDP')

model.run(20)
model.plot('wave', threshold, voltage)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7a504767f340> in <module>
#       8
#       9 model.run(20)
# ---> 10 model.plot('wave', threshold, voltage)
#
# NameError: name 'threshold' is not defined

# %%
model.run(50)
model.plot()
